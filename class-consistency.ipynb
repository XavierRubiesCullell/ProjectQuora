# %%
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
kaggle = True   # boolean setting whether the environment is Kaggle or not
saved_model = False   # saved, original (transformer)

# %%
# Scripts files
if kaggle:
    from shutil import copyfile
    copyfile(src = "/kaggle/input/quorascripts/input_net.py", dst = "../working/input_net.py")
    copyfile(src = "/kaggle/input/quorascripts/utils.py", dst = "../working/utils.py")

import utils
import input_net

# Packages
from os import path
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import time
import random
import datetime
from torch.utils.data import TensorDataset, random_split
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from sklearn.model_selection import train_test_split

# Transformers
from transformers import BertConfig, BertForSequenceClassification, BertTokenizer
# Out:
# Using TensorFlow backend.
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.

# %%
if torch.cuda.is_available():

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla P100-PCIE-16GB

# %% [markdown]
# ## Models

# %%
model_class = BertForSequenceClassification
tokenizer_class = BertTokenizer
tokenizer_model = 'bert-base-uncased'
tokenizer = tokenizer_class.from_pretrained(tokenizer_model, do_lower_case=True)

if saved_model:
    if kaggle:
        pretrained_model = "/kaggle/input/trained-model"
    else:
        pretrained_model = "models"
else:
    pretrained_model = 'bert-base-uncased'
model = model_class.from_pretrained(pretrained_model, num_labels=2, output_attentions = False, output_hidden_states = False).to(device)

if device == "cuda":
    model.cuda()
print("Model loaded")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# Model loaded

# %% [markdown]
# ## Input

# %%
max_len = 70
if kaggle:
    INPUT_NET = '/kaggle/input/quora-data/data/data/70/input70_bert-base-uncased.csv'
    TRAIN = "/kaggle/input/quora-data/train.csv"
else:
    INPUT_NET = "data/input.csv"
    TRAIN = "data/train.csv"
df = pd.read_csv(INPUT_NET)
df_train = pd.read_csv(TRAIN).fillna("")

# %%
ids = df_train[["qid1", "qid2"]]

# %%
df = np.array(df)

X_i, X_s, X_p, y = utils.ToTensor(df[:,:-1],df[:,-1])

dataset = TensorDataset(X_i, X_s, X_p, y)

seed_val = 47
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
batch_size = 256

execution_dataloader = DataLoader(
    dataset, # The samples.
    sampler = SequentialSampler(dataset), # Pull out batches sequentially.
    batch_size = batch_size # Evaluate with this batch size.
)

print("Number of execution batches:", len(execution_dataloader))
# Out:
# Number of execution batches: 1580

# %%
def execute1():
    '''
    Execute the model in order to obtain predicted classes
    - output:   nodes: dictionary of sentences id
                classes: dictionary of classes
    '''
    nodes = {}
    classes = {}
    model.eval()

    start = time.time()
    with torch.no_grad():
        for step, batch in enumerate(execution_dataloader):
                
            y = batch[3].to(device)

            out = model(input_ids=batch[0].to(device), token_type_ids=batch[1].to(device), attention_mask=batch[2].to(device), labels=y)[1] # using bert
            out = F.softmax(out, dim=1)
            pred = torch.max(out, 1)[1]

            for i in range(len(y)):
                pos = step*batch_size + i
                f = ids.iloc[pos,0]
                s = ids.iloc[pos,1]
                utils.e(f,s, nodes, classes)
                if pred[i] and nodes[f] != nodes[s]:
                    utils.class_join(f,s, nodes, classes)
            
    end = time.time()
    epoch_time = utils.format_time(end-start)

    print("time:", epoch_time)

    return nodes, classes

# %%
nodes, classes = execute1()
# Out:
# time: 0:12:58

# %%
print("There are", len(classes), "different question classes")
# Out:
# There are 439365 different question classes

# %%
sizes = {}
for cl in classes:
    l = len(classes[cl])
    if not l in sizes:
        sizes[l] = 0
    sizes[l] += 1

assert sum(sizes.values()) == len(classes)

# %%
for size in sorted(sizes):
    print(size, ": ", sizes[size], sep="")
# Out:
# 1: 375625
# 2: 50414
# 3: 7743
# 4: 2434
# 5: 1142
# 6: 603
# 7: 338
# 8: 234
# 9: 182
# 10: 106
# 11: 83
# 12: 63
# 13: 51
# 14: 43
# 15: 40
# 16: 24
# 17: 31
# 18: 15
# 19: 16
# 20: 9
# 21: 9
# 22: 16
# 23: 13
# 24: 5
# 25: 7
# 26: 7
# 27: 6
# 28: 9
# 29: 6
# 30: 7
# 31: 1
# 32: 4
# 33: 3
# 34: 3
# 35: 4
# 36: 3
# 37: 3
# 38: 3
# 39: 2
# 40: 2
# 41: 4
# 42: 3
# 43: 4
# 44: 1
# 45: 2
# 46: 1
# 47: 2
# 49: 1
# 50: 2
# 51: 1
# 52: 1
# 53: 1
# 56: 1
# 57: 2
# 58: 2
# 61: 1
# 63: 1
# 64: 4
# 65: 2
# 66: 1
# 70: 2
# 75: 1
# 76: 4
# 77: 1
# 82: 1
# 84: 2
# 97: 1
# 108: 1
# 110: 1
# 129: 2
# 145: 1
# 219: 1
# 260: 1

# %%
if kaggle:
    SENTENCES = "/kaggle/input/quora-data/sentences.csv"
else:
    SENTENCES = "data/sentences.csv"
sentences = pd.read_csv(SENTENCES)

# %%
N_sizes = 10
N_classes = 5
count = [N_classes]*N_sizes
sel_classes = {}

max_cl = None
for cl, cl_nodes in classes.items():
    size = len(cl_nodes)
    if size >= 3 and size < N_sizes+3 and count[size-3] > 0  or  size == max(sizes.keys()):
        if size == max(sizes.keys()):
            max_cl = cl  #we are curious to study the largest class that exists
        else:
            count[size-3] -= 1
        sel_classes[cl] = cl_nodes
    
    if sum(count) == 0 and max_cl:
        break

sel_classes
# Out:
# {25: [25, 26, 114035],
#  27: [27, 28, 50277],
#  41: [41, 42, 209447],
#  50: [50, 233769, 233961, 357323],
#  53: [53, 441812, 522141],
#  63: [63, 64, 43889],
#  99: [99, 100, 105314, 102419, 157960, 462304, 11667, 125444],
#  107: [107, 108, 652, 208937, 128657, 128658, 248362, 78036],
#  116: [116, 180358, 116185, 116186, 145706, 180988, 338518],
#  125: [125,
#   126,
#   90436,
#   90437,
#   101336,
#   163544,
#   180911,
#   142034,
#   7417,
#   7418,
#   82067],
#  130: [130, 141412, 141413, 169346, 198214],
#  135: [135, 136, 10657, 38442, 38443, 52814, 101659, 8378, 8379, 12753, 12754],
#  143: [143, 144, 219989, 462802],
#  187: [187, 188, 68732, 68733, 144864, 202157, 364823, 434871, 394711, 394712],
#  227: [227, 228, 112374, 46820, 46821, 232768],
#  251: [251,
#   252,
#   33925,
#   145833,
#   114241,
#   114242,
#   82212,
#   146944,
#   272834,
#   37817,
#   37818,
#   447995],
#  255: [255, 256, 8031, 8032],
#  268: [268, 274051, 274052, 430444],
#  313: [313, 314, 71619, 71620, 355262],
#  337: [337, 338, 133940, 133941, 233395, 320961],
#  365: [365, 366, 51686, 54934, 72718, 84985],
#  379: [379, 380, 29976, 45646, 45647, 261886],
#  387: [387, 388, 110985, 77095],
#  397: [397, 398, 2274, 2275, 79257, 177241, 177242, 210144, 258031, 283234],
#  401: [401, 402, 636, 637, 7319, 128644, 147732, 194717, 303684],
#  405: [405, 406, 17146, 104826, 104827],
#  443: [443, 194728, 194729, 212932, 275842],
#  459: [459, 460, 93291, 93292, 109081, 15150, 98060, 98061, 264790],
#  471: [471, 472, 82571, 82572, 311624],
#  511: [511, 512, 59488, 43199, 43200, 121335, 415501],
#  568: [568, 569, 36751, 101583, 5511, 86969, 8268, 92406, 214223, 299553],
#  572: [572, 573, 119577, 199376, 236532, 313438, 483675],
#  589: [589, 64582, 64583, 65904, 97472, 193729],
#  592: [592, 593, 7378, 59949, 36052, 36053, 73803, 73804, 154585, 441039],
#  639: [639, 29691, 94062, 31503, 83825, 206920, 468758],
#  758: [758, 759, 146322, 27131, 27132, 153030, 158036],
#  786: [786, 787, 147569, 147570, 25667, 114121, 114122, 299837],
#  792: [792,
#   793,
#   86348,
#   23555,
#   23556,
#   31174,
#   85305,
#   85306,
#   209874,
#   60132,
#   64422,
#   64423],
#  798: [798,
#   799,
#   38523,
#   11511,
#   11512,
#   7721,
#   7722,
#   172224,
#   93744,
#   93745,
#   119479],
#  808: [808, 809, 40065, 8159, 8160, 135295, 119578, 119579, 227862],
#  890: [890, 891, 26893, 26894, 83712, 96544, 213958, 241868, 160895],
#  898: [898,
#   899,
#   79264,
#   82155,
#   138189,
#   21339,
#   21340,
#   35177,
#   35178,
#   63254,
#   216895,
#   331742],
#  1066: [1066,
#   1067,
#   76010,
#   67173,
#   67174,
#   140439,
#   193992,
#   120649,
#   120650,
#   224137,
#   467434],
#  1070: [1070, 1071, 2739, 59922, 143544, 39275, 39276, 87333, 87332],
#  1074: [1074, 1075, 6617, 137106, 84422, 84423, 152375, 183829],
#  1158: [1158, 1159, 133136, 151172, 265847, 285493, 363157, 391443],
#  1272: [1272,
#   1273,
#   6265,
#   9283,
#   8260,
#   8261,
#   64080,
#   90661,
#   148478,
#   162771,
#   289300,
#   364692],
#  1465: [1465,
#   1466,
#   76491,
#   83301,
#   83302,
#   83364,
#   116692,
#   365558,
#   203569,
#   203570,
#   463850],
#  1513: [1513,
#   1514,
#   33774,
#   33775,
#   47178,
#   51956,
#   194572,
#   206827,
#   217521,
#   349555,
#   151535,
#   151536],
#  1781: [1781,
#   1782,
#   52792,
#   79745,
#   57946,
#   57947,
#   133293,
#   127638,
#   250494,
#   282455],
#  1919: [1919,
#   1920,
#   11600,
#   18952,
#   25994,
#   14810,
#   14811,
#   73571,
#   82436,
#   89282,
#   11069,
#   11070,
#   45052,
#   62369,
#   85443,
#   96291,
#   105692,
#   16064,
#   16065,
#   45050,
#   110622,
#   6119,
#   6120,
#   118125,
#   2559,
#   9036,
#   9037,
#   9826,
#   9827,
#   20607,
#   11091,
#   11092,
#   4044,
#   10946,
#   13049,
#   9171,
#   9172,
#   4506,
#   4507,
#   10321,
#   10322,
#   23803,
#   2711,
#   2712,
#   11373,
#   11263,
#   11264,
#   15547,
#   17456,
#   19199,
#   19200,
#   31712,
#   35414,
#   36495,
#   36569,
#   37175,
#   3595,
#   3596,
#   5715,
#   7016,
#   8685,
#   17100,
#   17135,
#   7445,
#   7446,
#   10329,
#   10330,
#   16346,
#   29357,
#   30554,
#   39426,
#   41484,
#   9899,
#   9900,
#   16199,
#   19500,
#   20010,
#   24471,
#   25820,
#   28722,
#   24861,
#   24862,
#   27331,
#   43544,
#   43784,
#   47230,
#   48654,
#   14695,
#   14696,
#   14926,
#   14927,
#   33427,
#   28132,
#   28133,
#   38255,
#   41669,
#   10562,
#   10563,
#   43605,
#   53632,
#   55530,
#   60263,
#   38362,
#   44317,
#   44318,
#   53467,
#   65109,
#   67303,
#   60503,
#   60504,
#   65116,
#   68431,
#   69079,
#   3794,
#   3795,
#   10796,
#   41598,
#   47818,
#   48082,
#   66256,
#   72620,
#   5358,
#   5359,
#   55061,
#   59385,
#   66410,
#   75917,
#   21716,
#   24473,
#   59855,
#   59856,
#   80153,
#   80301,
#   81027,
#   82022,
#   83500,
#   85165,
#   86522,
#   88319,
#   7707,
#   7708,
#   91424,
#   92278,
#   99661,
#   74655,
#   74656,
#   105925,
#   35931,
#   106997,
#   111301,
#   114804,
#   35932,
#   57359,
#   123624,
#   123836,
#   133845,
#   134237,
#   137496,
#   138134,
#   142869,
#   144396,
#   145489,
#   145914,
#   146730,
#   158845,
#   162836,
#   175417,
#   168087,
#   168088,
#   162538,
#   162539,
#   192859,
#   115459,
#   196364,
#   197620,
#   199520,
#   181292,
#   181293,
#   211886,
#   2049,
#   6771,
#   6772,
#   45349,
#   18857,
#   18858,
#   39223,
#   57107,
#   27405,
#   27406,
#   29373,
#   29374,
#   84535,
#   136136,
#   21242,
#   21243,
#   178178,
#   179678,
#   184643,
#   27082,
#   27083,
#   167858,
#   121509,
#   121510,
#   222156,
#   227601,
#   230995,
#   240809,
#   241356,
#   255882,
#   259519,
#   265297,
#   277944,
#   296498,
#   302490,
#   302540,
#   310176,
#   240253,
#   240254,
#   139755,
#   346920,
#   135652,
#   371334,
#   375811,
#   381161,
#   386010,
#   103098,
#   144871,
#   144872,
#   390962,
#   37660,
#   37661,
#   122865,
#   396785,
#   397622,
#   400675,
#   254281,
#   254282,
#   297580,
#   305640,
#   407036,
#   407911,
#   204524,
#   204525,
#   418888,
#   427006,
#   450453,
#   86826,
#   86827,
#   35736,
#   463432,
#   467999,
#   478710,
#   352038,
#   450722,
#   490105,
#   65283,
#   505282,
#   508882,
#   520998,
#   496165]}

# %% [markdown]
# We look at the sentences in the class with more questions

# %%
for nod in classes[max_cl]:
    print(sentences.iloc[nod,0])
# Out:
# How can I gain healthy weight and mass?
# What kind of animal did this?
# What is the best way to make a responsive grid of "diamond shapes"?
# How can you speak and learn fluent English like Karan Johar?
# Why does my DIRECTV guide read "to be announced"?
# Doing excessive masturbation is a cause of less weight. How do I gain weight naturally?
# What is the property tax rate in Granville, Ohio? How is it compared to the one of Washington?
# In graphic cards which matters more, the number of CUDA cores or the speed of the graphic card?
# What would happen if you cut out refined sugar entirely?
# How can we tell if the blue I see is the same blue you see?
# What are some of the best ways to gain weight in a healthy way?
# What book can you recommend me, that gives an electrical engineer an introduction to financial & business world?
# Is The Carbonaro Effect staged?
# What is the advantage of being a woman in computer science?
# I just read that Indian developers can sell their Android apps but I'm unable to change my country to India. How can I change my country?
# A seller gave 15% discount on MP of bat that is 30₹. He gave a ball of price 1.5₹ for free with bat & made a profit of 20%. Find the Cost of bat?
# How are Rajya Sabha members elected?
# How can I gain weight?
# Is Spotify the next Napster?
# How can I legally get free iPod music?
# what is the difference between current and electricity?
# What should I do to gain some weight?
# What you guys think about ecommerce ecosystem of kerala?
# What are good skills to have?
# How can I make money online in India?
# What is the easiest way to lose weight faster?
# What is a black hole? How can we understand it?
# How do I lose weight fast?
# How do I set up a restaurant?
# What are peripheral pulses? Where are they located?
# How do I lose weight in a short time?
# How can Activia yogurt aid with weight loss?
# If you were given a chance to be somebody else for a day, who would you be?
# Why do I always become bored in relationships?
# My grandfather is 92 yrs old & is diagnosed with infection in both of his lungs. Docs hv sggstd surgery. What should we do?
# How do I lose weight and reduce my waist quickly?
# Is it possible to change your personality as a child?
# How can I efficiently lose weight?
# What are your absolute favorite 7 books?
# How can I lose 4kg weight?
# Suppose you are an evolutionist and atheist (as am I), what is your motivation to live if all there is, is life and death?
# Should I heat my room with a ceramic tower heater or an oil-filled radiator?
# What are the best way of loose the weight?
# How do you get noticed?
# What is the difference between Computer Engineering and Computer Science and Engineering? Which one has more opportunities and future?
# What are the best was to lose weight?
# How hard is it to practice water polo compared to aquajogging?
# How can I keep the peace of mind?
# Is there a medication for Aspergers?
# How can I slowly lose weight?
# I feel sleepy all the day, what should I do?
# How do I prepare for TOEFL exam?
# What is the barrier to entry for the real estate job market?
# How do I make a simple cake?
# I am in 10th grade. My subject is computer.Which courses should I take in the future to have better life?
# What's the best perfume under Rs.500 for men in India?
# How do I suck it up and lose weight?
# Which is the best iPhone 6 case?
# How much will the price of gold fall?
# What is the difference between a premier and authentic NHL jersey?
# How can we stop racism?
# How does surface tension work?
# What is the county of Edgware and how does the lifestyle compare to the London Borough of Newham?
# What should you do if you want to lose a lot of weight?
# Am I a good looking girl or not? Will anyone like me ever or not?
# How do I lose weight?
# Why people don't worship bramha ji? Niether I have seen temples of bramha ji nor festival where people worship bramha ji?
# How can I deal with my conversationally narcissistic roommate?
# Why do you always collapse my answer, Quora?
# Can yelp list the menu and any other publically available information about a restaurant without approval from the restaurant?
# Why is it difficult to say NO?
# Where can I find peer reviewed articles on recruitment?
# What are the best ways to lose a lot of weight as quickly as possible?
# Was Michael Jackson all time great dancer with his timing and pure perfection moves?
# What is the work culture of stqc?
# Why can't my girlfriend reach orgasm through normal intercourse and only from oral sex?
# What is a secret which you would not tell anybody in real life?
# Is there a war coming?
# Is it okay to exercise twice a day?
# What's your favourite colour?
# How can I lose max weight in 14 days?
# What can repel electrons?
# How can I balance gaming and studying?
# In networking why classA has only 8 bits for identifying network?
# What are the best M.Tech streams for mechanical engineers?
# Out of all the beaches in Goa, which one is the best beach to go to?
# Why are Indians so overdramatic?
# How can I lose 25 kg?
# What is the difference between hardware decoding and software decoding?
# How do I lose weight without quitting?
# How can I find a live in partner easily in New Delhi?
# What if humans are colorblind, and colorblind people aren't?
# How should I lose weight?
# How do I hack a Wi-Fi password from a laptop?
# In the hit TV series Mash, which actor was in both Mash and Happy Days?
# What are some inspirational things about Michael Phelps?
# How should one change their diet to lose weight?
# The decision of Indian Government to demonetize ₹500 and ₹1000 notes? Is Right or wrong?
# Are pyramid schemes illegal?
# What are important things for people intending to major in agriculture to know about?
# How can I make my life better?
# What is the story of your personal failure in life?
# I have to reduce my weight by 15 kgs. What is the healthy rate at which I should aim to reduce per month? 21yr old-female-66kg-5.2ft?
# How do I lose fats and excessive weight from body?
# What are the future methodology changes in the  government sector examinations ?
# How and why is the universe expanding?
# What is the procedure to get admission in nit's for lateral entry b.tech courses?
# Is drinking Coca Cola bad for health?
# How can I loose weight in a week?
# What are good eating habits of successful people?
# What is the most beautiful word in Hindi?
# What are some names starting with "Du" or "Doo" or "Jha" for a baby girl?
# why do I have a lot of dreams ?
# What is the best way to loose weight quickly?
# What is the difference between transgender man and transgender woman?
# What are the benefits of the egg white?
# What lessons can we learn from Jewish success?
# What kinds of things besides marijuana cause short-term memory loss?
# I am getting fat on my lower body and on the chest, is there any way I can get fit without looking skinny fat?
# How do you cover up a tattoo with makeup?
# What happens to the boundary layer thickness if fluid velocity increases?
# What are the best things to do when working on losing weight?
# How is Marco Pierre White seen in the industry?
# Which is the best RO water purifier in India?
# What is the best investment in India?
# What jobs can I do with a math major?
# Who was a role model for Mark Zuckerberg?
# How do I find my lost android phone?
# What are the types of circuit breakers?
# What should be my proper diet for weight loss?
# How legit is goherenext.com?
# How can one attain complete nirvana?
# I want to buy a smartphone under Rs. 14000 which has good performance and camera quality, so which smartphone should I buy?
# Can anyone tell about the future options after joining axtria as a technical analyst?
# What are the best way to invest money?
# How does orange juice help relieve a sore throat?
# How do I continue doing my homework when I'm tired and just want to sleep?
# Why Democracy index 2012 assigned India to flawed Democracy category?
# What is meant by bias?
# How do I lose 45 pounds the easiest way if I have cravings?
# Total instantaneous power supplied by a 3 phase A.C supply to a balanced RC load is?
# What did Sauron look like?
# In the movie Interstellar, Cooper sees Murph sitting in her room after he reaches the 5D world. Does it mean that the light reflected off of Murph crosses the spacetime barrier of 3D world & enters Cooper's 5D world? If Cooper can see Murph, why can't she see him? Principle of reversibility right?
# My little sister is now much taller than I am, I feel extremely jealous, what can I do?
# What are best tips for weight loss?
# What is a good inpatient drug and alcohol rehab center near Newton County GA?
# Where can I find a good, deep, comprehensive overview of CDN services? How do you decide what is the best CDN service?
# How do I lose 5 kg weight within 7 days?
# What are some superstitions about dreams?
# How can I prove if f monotone function on an interval then f is measurable on interval?
# Which is the stronger acid propionic acid, acetic acid or formic acid?
# Is there any easy way to make money online?
# What is a business model?
# Honesty: What are things people pretend not to like but actually enjoy?
# Why do I experience chest pain while I playing football (Soccer)?
# Is University of Surrey hard to get into?
# Who needs market research report?
# What is the difference between SCJP and OCJP certification?
# What is a good resource to find all market data for any industry?
# Which questions is Quora unsuited for?
# What is physical quantities and also its types?
# I read that the The Banach-Tarski paradox applies in math. Does it apply in the real world?
# Is there a clean [without expletives] version of the Hitchhiker's Guide to the Galaxy?
# What are some fun things to do so you don't get bored on Friday night?
# Who was the first slave owner?
# Why does my guitar sound low?
# What are the differences between metaphors and personification? What are some good examples?
# How do I start a fitness routine to lose weight?
# Has Trump initiated as many lawsuits as 2,000 by Erdogan of Turkey?
# What is the best exersice for weight loss?
# What are the side effects of use of flaxseed oil?
# Which is the better post-hoc test technique between Nemeniyi and Wilcoxon-sign-rank test for Friedman test?
# What is a diet to lose 10 pounds per week?
# How can I stop being so boring?
# How do I qualified to work?
# Where can I hire friendly and well-trained specialists in Sydney for fire protection?
# What is the most easiest way to lose weight?
# Who do you think might support an initiative to create a method of written/visual communication that visibly depicts the communicative value of oral communication - the spoken word?
# What is the best way to find good old Tamil songs?
# Does Stripe or Square-Up act as an "agent" to process money transfer or do they also come under the payment processor license in USA?
# Which is the best food to gain weight?
# How is a TF card different from an SD card?
# What is the best way to reheat a Domino's Pizza to retain its flavor?
# What is the best diet to gain weight?
# Whey is the sky blue?
# PM Modi has abolished 500 and 1000 Rs notes to check black money. Is it a sign that Modi is the best and the greatest Prime Minister India till now?
# Should prostitution be legalized in India?
# Which foods help gain weight?
# What are the innovative decisions taken by Delhi AAP Government, which makes them different from other parties?
# What is the proper diet to gain weight?
# Why is India not a member of NATO?
# Which are the best old Hindi (Bollywood) romantic songs for a couple dance?
# How do footballers get paid? Do they get their weekly wage even when there is no league match during that week?
# What are the best foods and/or diet plan for weight gain?
# What is the difference between 4g LTE and VoLTE? Which phone should I buy one with VoLTE or only 4G.
# What are the differences between Android and iOS in multitasking?
# Do you know Sany Indian?
# Is a person seen as online during a WhatsApp call?
# I am a 13 year old girl, and I am overweight. I am 5 feet 5 inches tall, and weigh 120 pounds. How do I lose weight?
# How do you update Jiffies?
# What do use to create a gaming fansite? Wordpress vs Enjin?
# What is a weight loss strategy that works?
# Why did Bill Clinton win so many Southern States?
# What things in life are worth dying for?
# What is a Software Requirement Specification?
# What is the difference between a graduate of mechanical engineering and a mechanic?
# Who are the best personal financial advisors in Green Bay for people saving for retirement? What were your experiences with them?
# What is it like working in an investment bank?
# How do you determine when your mail is being delivered?
# What happens if the whole world uses the same currency?
# What are the companies whose stocks are worth buying right now?
# What are the main differences between a bachelor's and a graduate degree in sociology in terms of career prospects?
# How hard is CFA level 1, given you are a economic graduate from DU?
# What natural resources are found in the Southeast US?
# How can I avoid the habit of masturbating?
# Why we should read Quora?
# How can a 14 year old lose weight and get fit?
# How can you explain quantum mechanics to a 9 year old?
# What is self mimicry and what is an example?
# What are the main functions of epidermal cells?
# How do I workout without losing weight?
# What is happening with Kashmir?
# Why do celebrities always wear sunglasses?
# Which English font is used most commonly in documents of Government of India offices?
# What are the most and least followed topics on Quora in 2016?
# My H1 extension and my wife's H4 EAD are approved based on I140 from company A till 2018. If I switch to company B will my wife H4 EAD be valid?
# How do I lose weight fast and naturally?
# What does the phrase "Every prophet in his house" mean?
# Why did India become poor if it was once so very rich as claimed by many Indians? The examples given are that of diamonds which were sold on the streets in India during the rule of Krishnadevaraya.
# How do you lose 20 lbs fast?
# What would've happened if the South won the Civil War?
# Why doesn't the US navy use azimuth propellers on warships?
# Do different colored eyes see differently?
# How do I stop being such a racist?
# Have people become more judgemental and more reactive in the modern era?
# How do I burn fat?
# How many hours should it take to integrate Elasticsearch API with Laravel?
# What is the best Fitness Band?
# Does smoking causes headaches?
# How accurately does Scott Patterson's The Quants portray the lives of quants on Wall Street?
# How do you get rid of a bump on your face?
# I want to lose weight, can you tell me some tips to help me?
# Can a breath smells for short period?
# How is the GATE paper pattern by IISC Bangalore different from the IITs for the architecture and planning branch?
# Is it possible to develop a website in which student records can be stored in a database through a form by using WordPress, Joomla or Drupal?
# How do I save money in Chennai?
# What are the best and healthiest ways to lose weight?
# At first, it was a click, then a touch. And after that, what's next in digital interaction?
# How can I add my profile picture on Qoura?
# What is the best way to clean an engine?
# What is a paradox in figurative speech? What are some examples?
# What is the tax id number for KMJ Realty, LLC?
# How many keywords are there in Gosu programming language in the latest version?
# What is a productized service?
# Is it bad to take pictures/videos while rushing frats?
# What is the best site to download YouTube downloader?
# Why do guys don't like smart girls?
# Is it better to have a girl as a good friend or a girl friend?
# I want to earn money online at home what is the simplest way?
# I'm a 14 year old boy who is around 5.8 and I weigh about 106 pounds. I go to the gym and do weight training 3-5 times a week and eat lots of food. Am I under weight? If so, how do I gain weight?

# %% [markdown]
# It has a lot of "random" sentences, but in fact, many questions talk about losing weight

# %% [markdown]
# We build the dataframe that will be processed to build the input of the model. We additionally store the ids of the questions as we will need them in order later on.

# %%
questions_ab = pd.DataFrame(columns = ["question1", "question2"])
ids = pd.DataFrame(columns = ["id1", "id2"])
ind = 0
for cl, cl_nodes in sel_classes.items():
    for i in range(len(cl_nodes)-1):
        for j in range(i+1, len(cl_nodes)):
            questions_ab.loc[ind, "question1"] = sentences.iloc[cl_nodes[i],0]
            questions_ab.loc[ind, "question2"] = sentences.iloc[cl_nodes[j],0]
            ids.loc[ind,"id1"] = cl_nodes[i]
            ids.loc[ind,"id2"] = cl_nodes[j]
            ind += 1
    
questions_ab["is_duplicate"] = [1] * ind

# %%
data = input_net.create_input(questions_ab, tokenizer_class, tokenizer_model, max_len, out_file = None)
# Out:
# Dataset length: 35095
# Pretrained model used: bert-base-uncased
# Maximum sequence length: 70

# %% [markdown]
# ### Evaluation

# %%
data = np.array(data)

X_i, X_s, X_p, y = utils.ToTensor(data[:,:-1],data[:,-1])

dataset = TensorDataset(X_i, X_s, X_p, y)

seed_val = 47
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
execution_dataloader = DataLoader(
    dataset, # The samples.
    sampler = SequentialSampler(dataset), # Pull out batches sequentially.
    batch_size = batch_size # Evaluate with this batch size.
)

print("Number of execution batches:", len(execution_dataloader))
# Out:
# Number of execution batches: 138

# %%
def execute2():
    '''
    Predict all the combinations of sequences
    - output    acc: accuracy value
    '''
    acc = 0
    model.eval()
    
    start = time.time()
    with torch.no_grad():
        for step, batch in enumerate(execution_dataloader):
                
            y = batch[3].to(device)
            out = model(input_ids=batch[0].to(device), token_type_ids=batch[1].to(device), attention_mask=batch[2].to(device), labels=y)[1] # using bert
            out = F.softmax(out, dim=1)
            pred = torch.max(out, 1)[1]

            acc += sum(pred).item()
    
    acc = acc/len(data)*100
    end = time.time()    
    print("time:", utils.format_time(end-start))
    
    return acc

# %%
print("Accuracy is {:.2f}".format(execute2()),"%", sep="")
# Out:
# time: 0:01:06
# Accuracy is 2.70%

# %% [markdown]
# Accuracy is extremely low.
